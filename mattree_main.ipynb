# %% [markdown]
# # Setting the work directory

# %%
### Run just once
### Assuming a google colab exection by drive
from google.colab import drive
import os

drive.mount('/content/drive')

current_path = os.getcwd()
if current_path == '/content/drive/MyDrive/Colab Notebooks/mat_tree':
  print(f"current path: {current_path}. At the corret path.")
else:
  print(f"current path:{current_path}. Moving to correct path.")
  os.chdir("drive/MyDrive/Colab Notebooks/mat_tree/")
  print(f"current path: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# current path:/content. Moving to correct path.
# current path: /content/drive/MyDrive/Colab Notebooks/mat_tree

# %% [markdown]
# # Libs

# %%
import pandas as pd
from IPython.display import display

### importing algorihm functions
from scripts.algorithm.TreeNodeObject import TreeNodeObject
from scripts.algorithm.dashtree import dashtree
from scripts.algorithm.graphic_tree import generate_graphic_tree
from scripts.utils import get_dataset

# %% [markdown]
# # Algorithm execution

# %%
df = get_dataset("fsny_10")

# %%
### var: exclude_aspects
### A list of aspects to exclude for clustering or a empty list to use all aspects.
### e.g.: exclude_aspects = [] # use all aspects
###       exclude_aspects = ['day', 'weather', 'root_type'] # exclude aspects for fsny
###       exclude_aspects = ['data', 'idVotacao', 'parlamentar'] # exclude aspects for basometro
exclude_aspects = ['day', 'weather', 'root_type']

print("Iniciando MAT-Tree")
self = TreeNodeObject(df=df)
# # eda_dashboard('ALL', df, self)
dashtree(self, df, exclude_aspects)
# Out:
# Iniciando MAT-Tree
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py:3757: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.9/dist-packages/numpy/core/_methods.py:222: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.9/dist-packages/numpy/core/_methods.py:256: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-87d6678de5bc> in <cell line: 11>()
#       9 self = TreeNodeObject(df=df)
#      10 # # eda_dashboard('ALL', df, self)
# ---> 11 dashtree(self, df, exclude_aspects)
#
# /content/drive/MyDrive/Colab Notebooks/mat_tree/scripts/algorithm/dashtree.py in dashtree(self, df, exclude_aspects)
#     104             for c in self.freqMatrix.columns:
#     105                 initial_variance = self.freqMatrix[c].var()
# --> 106                 variance_reduction = initial_variance - abs((np.var(esquerda[c]) - np.var(direita[c])) / 2)
#     107                 reducao[c] = variance_reduction
#     108             split_value[col] = sum(reducao.values()) / len(self.freqMatrix.columns)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3772                 or key in self.columns.drop_duplicates(keep=False)
#    3773             ):
# -> 3774                 return self._get_item_cache(key)
#    3775
#    3776             elif is_mi and self.columns.is_unique and key in self.columns:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in _get_item_cache(self, item)
#    4281
#    4282             loc = self.columns.get_loc(item)
# -> 4283             res = self._ixs(loc, axis=1)
#    4284
#    4285             cache[item] = res
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    3729
#    3730             col_mgr = self._mgr.iget(i)
# -> 3731             result = self._box_col_values(col_mgr, i)
#    3732
#    3733             # this is a cached value, mark it so
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in _box_col_values(self, values, loc)
#    4264         klass = self._constructor_sliced
#    4265         # We get index=self.index bc values is a SingleDataManager
# -> 4266         return klass(values, name=name, fastpath=True).__finalize__(self)
#    4267
#    4268     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     360             if fastpath:
#     361                 # e.g. from _box_col_values, skip validation of name
# --> 362                 object.__setattr__(self, "_name", name)
#     363             else:
#     364                 self.name = name
#
# KeyboardInterrupt:
