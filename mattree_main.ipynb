# %% [markdown]
# # Setting the work directory

# %%
### Run just once
### Assuming a google colab exection by drive
from google.colab import drive
import os
import warnings

warnings.filterwarnings('ignore')

drive.mount('/content/drive')

current_path = os.getcwd()
if current_path == '/content/drive/MyDrive/Colab Notebooks/mat_tree':
  print(f"current path: {current_path}. At the corret path.")
else:
  print(f"current path:{current_path}. Moving to correct path.")
  os.chdir("drive/MyDrive/Colab Notebooks/mat_tree/")
  print(f"current path: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# current path:/content. Moving to correct path.
# current path: /content/drive/MyDrive/Colab Notebooks/mat_tree

# %% [markdown]
# # Libs

# %%
import pandas as pd
from IPython.display import display

### importing algorihm functions
from scripts.algorithm.TreeNodeObject import TreeNodeObject
from scripts.algorithm.dashtree import dashtree
from scripts.algorithm.graphic_tree import generate_graphic_tree
from scripts.utils import get_dataset

# %% [markdown]
# # Algorithm execution

# %%
df = get_dataset("fsny_10")### fsny_10, fsny_193, basometro
# df.head()
# df.info()

# %%
# df.memory_usage()

# %%
### var: exclude_aspects
### A list of aspects to exclude for clustering or a empty list to use all aspects.
### e.g.: exclude_aspects = [] # use all aspects
###       exclude_aspects = ['day', 'weather', 'root_type'] # exclude aspects for fsny
###       exclude_aspects = ['data', 'idVotacao', 'parlamentar'] # exclude aspects for basometro
exclude_aspects = ['day', 'weather', 'root_type']#, 'poi','type','time']

print("Iniciando MAT-Tree")
self = TreeNodeObject(df=df)
# # eda_dashboard('ALL', df, self)
dashtree(self, df, exclude_aspects)

### func para gerar a visualização da árvore e salvar como imagem
# generate_graphic_tree(self, 'path')

print("\nMAT-Tree is DONE!")
# Out:
# Iniciando MAT-Tree
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Computing aspects threshold...DONE!
# Starting trajectory split on branches (split method: binary). It will do:
# 	Check trajs for left and right branches regarding the AVG.
# 	Compute variance for each aspect and branch.
# 	Running...ALL DONE!
# self.division: type~Home (private)
# asp: type; val: Home (private)
# nodeLabel: [self.depth=0].append(self.id=Lvl 0)
# parentName: type
# [Home (private)]
#
# Chamar func para nó da ESQUERDA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Computing aspects threshold...DONE!
# Starting trajectory split on branches (split method: binary). It will do:
# 	Check trajs for left and right branches regarding the AVG.
# 	Compute variance for each aspect and branch.
# 	Running...ALL DONE!
# self.division: rating~9.0
# asp: rating; val: 9.0
# nodeLabel: [self.depth=1].append(self.id=Lvl 1 - 0)
# parentName: rating
# [9.0]
#
# Chamar func para nó da ESQUERDA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Computing aspects threshold...DONE!
# Starting trajectory split on branches (split method: binary). It will do:
# 	Check trajs for left and right branches regarding the AVG.
# 	Compute variance for each aspect and branch.
# 	Running...ALL DONE!
# self.division: type~Deli / Bodega
# asp: type; val: Deli / Bodega
# nodeLabel: [self.depth=2].append(self.id=Lvl 2 - 0)
# parentName: type
# [Deli / Bodega]
#
# Chamar func para nó da ESQUERDA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Stop criteria matched.
# self.done: Yes; self.parentName: 46; nodeLabel: [self.depth=3.append(self.id=Lvl 3 - 0)]
# leftChildName: 46; left.id: Lvl 3 - 0
#
# Chamar func para nó da DIREITA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Stop criteria matched.
# self.done: Yes; self.parentName: 49; nodeLabel: [self.depth=3.append(self.id=Lvl 3 - 1)]
# rightChildName: 49; right.id: Lvl 3 - 1
# leftChildName: type
# [Deli / Bodega]; left.id: Lvl 2 - 0
#
# Chamar func para nó da DIREITA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Computing aspects threshold...DONE!
# Starting trajectory split on branches (split method: binary). It will do:
# 	Check trajs for left and right branches regarding the AVG.
# 	Compute variance for each aspect and branch.
# 	Running...ALL DONE!
# self.division: rating~8.5
# asp: rating; val: 8.5
# nodeLabel: [self.depth=2].append(self.id=Lvl 2 - 1)
# parentName: rating
# [8.5]
#
# Chamar func para nó da ESQUERDA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Stop criteria matched.
# self.done: Yes; self.parentName: 50; nodeLabel: [self.depth=3.append(self.id=Lvl 3 - 2)]
# leftChildName: 50; left.id: Lvl 3 - 2
#
# Chamar func para nó da DIREITA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Stop criteria matched.
# self.done: Yes; self.parentName: 50; nodeLabel: [self.depth=3.append(self.id=Lvl 3 - 3)]
# rightChildName: 50; right.id: Lvl 3 - 3
# rightChildName: rating
# [8.5]; right.id: Lvl 2 - 1
# leftChildName: rating
# [9.0]; left.id: Lvl 1 - 0
#
# Chamar func para nó da DIREITA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Computing aspects threshold...DONE!
# Starting trajectory split on branches (split method: binary). It will do:
# 	Check trajs for left and right branches regarding the AVG.
# 	Compute variance for each aspect and branch.
# 	Running...ALL DONE!
# self.division: weather~Rain
# asp: weather; val: Rain
# nodeLabel: [self.depth=1].append(self.id=Lvl 1 - 1)
# parentName: weather
# [Rain]
#
# Chamar func para nó da ESQUERDA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Computing aspects threshold...DONE!
# Starting trajectory split on branches (split method: binary). It will do:
# 	Check trajs for left and right branches regarding the AVG.
# 	Compute variance for each aspect and branch.
# 	Running...ALL DONE!
# self.division: type~Metro Station
# asp: type; val: Metro Station
# nodeLabel: [self.depth=2].append(self.id=Lvl 2 - 2)
# parentName: type
# [Metro Station]
#
# Chamar func para nó da ESQUERDA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Stop criteria matched.
# self.done: Yes; self.parentName: 39; nodeLabel: [self.depth=3.append(self.id=Lvl 3 - 4)]
# leftChildName: 39; left.id: Lvl 3 - 4
#
# Chamar func para nó da DIREITA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Stop criteria matched.
# self.done: Yes; self.parentName: 40; nodeLabel: [self.depth=3.append(self.id=Lvl 3 - 5)]
# rightChildName: 40; right.id: Lvl 3 - 5
# leftChildName: type
# [Metro Station]; left.id: Lvl 2 - 2
#
# Chamar func para nó da DIREITA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Computing aspects threshold...DONE!
# Starting trajectory split on branches (split method: binary). It will do:
# 	Check trajs for left and right branches regarding the AVG.
# 	Compute variance for each aspect and branch.
# 	Running...ALL DONE!
# self.division: root_type~Arts & Entertainment
# asp: root_type; val: Arts & Entertainment
# nodeLabel: [self.depth=2].append(self.id=Lvl 2 - 3)
# parentName: root_type
# [Arts & Entertainment]
#
# Chamar func para nó da ESQUERDA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Stop criteria matched.
# self.done: Yes; self.parentName: 39; nodeLabel: [self.depth=3.append(self.id=Lvl 3 - 6)]
# leftChildName: 39; left.id: Lvl 3 - 6
#
# Chamar func para nó da DIREITA
# Computing frequency matrix...DONE!
# Computing absolute freq matrix...DONE
# Stop criteria matched.
# self.done: Yes; self.parentName: 39; nodeLabel: [self.depth=3.append(self.id=Lvl 3 - 7)]
# rightChildName: 39; right.id: Lvl 3 - 7
# rightChildName: root_type
# [Arts & Entertainment]; right.id: Lvl 2 - 3
# rightChildName: weather
# [Rain]; right.id: Lvl 1 - 1
#
# MAT-Tree is DONE!
